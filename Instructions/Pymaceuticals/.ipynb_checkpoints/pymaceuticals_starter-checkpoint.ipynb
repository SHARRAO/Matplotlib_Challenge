# %% [markdown]
# ## Observations and Insights

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata_df = pd.read_csv(mouse_metadata_path)
study_results_df = pd.read_csv(study_results_path)

# Combine the data into a single dataset
# Merge two dataframes using an outer join
mo_st_merge_df = pd.merge(mouse_metadata_df, study_results_df, on="Mouse ID", how="outer")

# Display the data table for preview
mo_st_merge_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
# The value_counts method counts unique values in a column
count = mo_st_merge_df["Mouse ID"].value_counts()
count
# Out:
# g989    13
# m550    10
# w914    10
# t565    10
# u327    10
#         ..
# t573     1
# v199     1
# x226     1
# b447     1
# o848     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# The unique method shows every element of the series that appears only once
unique = mo_st_merge_df["Mouse ID"].unique()
unique
# Out:
# array(['k403', 's185', 'x401', 'm601', 'g791', 's508', 'f966', 'm546',
#        'z578', 'j913', 'u364', 'n364', 'y793', 'r554', 'm957', 'c758',
#        't565', 'a644', 'i177', 'j989', 'i738', 'a520', 'w914', 'r811',
#        'g288', 'i334', 'q610', 'd251', 'l897', 'c458', 'b742', 'b128',
#        'j246', 'a411', 'j119', 'w150', 'v923', 'g316', 's710', 'l509',
#        'r944', 'e662', 'u196', 'q597', 'a444', 'i557', 'r921', 'w678',
#        'y449', 'a203', 'a251', 'a262', 'a275', 'a366', 'a401', 'a457',
#        'a492', 'a577', 'a685', 'a699', 'a788', 'a818', 'a897', 'a963',
#        'b313', 'b447', 'b487', 'b559', 'b759', 'b879', 'c139', 'c264',
#        'c282', 'c302', 'c326', 'c402', 'c559', 'c580', 'c757', 'c766',
#        'c819', 'c832', 'c895', 'c927', 'd133', 'd164', 'd474', 'e213',
#        'e227', 'e291', 'e476', 'e584', 'f129', 'f234', 'f278', 'f345',
#        'f394', 'f436', 'f545', 'f932', 'f993', 'g107', 'g296', 'g497',
#        'g558', 'g570', 'g867', 'g989', 'h246', 'h333', 'h428', 'h531',
#        'i386', 'i477', 'i635', 'i669', 'i901', 'j235', 'j296', 'j365',
#        'j755', 'j984', 'k210', 'k382', 'k483', 'k510', 'k603', 'k754',
#        'k804', 'k862', 'k894', 'l215', 'l264', 'l471', 'l490', 'l558',
#        'l661', 'l700', 'l725', 'l733', 'l872', 'm133', 'm269', 'm331',
#        'm550', 'm650', 'm756', 'n304', 'n482', 'n630', 'n671', 'n678',
#        'n763', 'n923', 'n967', 'o287', 'o302', 'o331', 'o523', 'o562',
#        'o725', 'o795', 'o809', 'o813', 'o848', 'o926', 'o973', 'p136',
#        'p189', 'p310', 'p387', 'p438', 'p981', 'q119', 'q132', 'q483',
#        'q511', 'q582', 'q633', 'q787', 'r107', 'r157', 'r604', 'r701',
#        'r850', 's121', 's141', 's152', 's166', 's187', 's337', 's565',
#        's619', 't198', 't451', 't573', 't718', 't724', 't994', 'u149',
#        'u153', 'u327', 'u946', 'v199', 'v289', 'v295', 'v339', 'v409',
#        'v603', 'v719', 'v764', 'v766', 'v835', 'v989', 'v991', 'w140',
#        'w151', 'w167', 'w193', 'w350', 'w422', 'w540', 'w575', 'w584',
#        'w697', 'w746', 'x111', 'x209', 'x226', 'x264', 'x336', 'x402',
#        'x581', 'x613', 'x773', 'x822', 'x930', 'y163', 'y260', 'y478',
#        'y601', 'y769', 'y865', 'z234', 'z314', 'z435', 'z581', 'z795',
#        'z969'], dtype=object)

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

mo_st_merge_df.drop_duplicates()
mo_st_merge_df. head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
new_df= mo_st_merge_df.drop_duplicates(['Mouse ID'], keep='last')
new_df.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9      k403     Ramicane    Male          21          16         45
# 19     s185    Capomulin  Female           3          17         45
# 29     x401    Capomulin  Female          16          15         45
# 39     m601    Capomulin    Male          22          17         45
# 49     g791     Ramicane    Male          11          16         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 9            22.050126                 1
# 19           23.343598                 1
# 29           28.484033                 0
# 39           28.430964                 1
# 49           29.128472                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Checking the number of mice in the clean DataFrame.
count_of_mice = new_df["Mouse ID"].value_counts()
count_of_mice
# Out:
# m550    1
# m601    1
# p438    1
# e227    1
# a492    1
#        ..
# h428    1
# o973    1
# z795    1
# a818    1
# m957    1
# Name: Mouse ID, Length: 249, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
Tumor = new_df['Tumor Volume (mm3)']
mean_numpy = np.mean(Tumor)
print(f"The mean tumor volume is {mean_numpy} ")

median_numpy = np.median(Tumor)
print(f"The median tumor volume is {median_numpy}")

var_numpy = np.var(Tumor,ddof = 0)
print(f"The tumor variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(Tumor,ddof = 0)
print(f"The tumor standard deviation using the NumPy module is {sd_numpy}")

# Generate a new 30 Tumor volume sample and caliculate the SEM of the sample
sample = new_df.sample(30)
print(f"The SEM value for the sample Tumor volume data is {sem(Tumor)}")
# Out:
# The mean tumor volume is 54.99913687738955
# The median tumor volume is 55.84141007
# The tumor variance using the NumPy module is 159.50787704180308
# The tumor standard deviation using the NumPy module is 12.62964279153623
# The SEM value for the sample Tumor volume data is 0.801983119246071

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
###### Filter the DataFrame down only to those columns to chart
Mouse_and_Regimen = new_df[["Mouse ID","Drug Regimen"]]

####### Set the index to be "Drug Regimen" so they will be used as labels
Mouse_and_Regimen = Mouse_and_Regimen.set_index("Drug Regimen")
Mouse_and_Regimen.head()
# Out:
#              Mouse ID
# Drug Regimen
# Ramicane         k403
# Capomulin        s185
# Capomulin        x401
# Capomulin        m601
# Ramicane         g791

# %%
Mouse_and_Regimen = new_df["Mouse ID"].value_counts()
####### Configure plot and ticks
Mouse_and_Regimen.plot(kind="bar", facecolor="red")

# %%
###### Use DataFrame.plot() in order to create a bar chart of the data
Mouse_and_Regimen.plot(kind="bar", figsize=(10,3))
Mouse_and_Regimen = new_df["Mouse ID"].value_counts()
###### Set a title for the chart
plt.title("Mouse Per Drug Regimen")

plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
######## Set x axis and tick locations
x_axis = np.arange(len(Mouse_and_Regimen))
tick_locations = [value for value in x_axis]

# %%
####### Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, new_df["Mouse ID"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, new_df["Drug Regimen"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="800">
# ([<matplotlib.axis.XTick at 0x22321e645e0>,
#   <matplotlib.axis.XTick at 0x22321e645b0>,
#   <matplotlib.axis.XTick at 0x2232001d7f0>,
#   <matplotlib.axis.XTick at 0x2232211e310>,
#   <matplotlib.axis.XTick at 0x2232211e820>,
#   <matplotlib.axis.XTick at 0x2232211ed30>,
#   <matplotlib.axis.XTick at 0x22322125280>,
#   <matplotlib.axis.XTick at 0x22322125790>,
#   <matplotlib.axis.XTick at 0x2232211e8b0>,
#   <matplotlib.axis.XTick at 0x22322125b20>,
#   <matplotlib.axis.XTick at 0x22322125e50>,
#   <matplotlib.axis.XTick at 0x2232212a3a0>,
#   <matplotlib.axis.XTick at 0x2232212a8b0>,
#   <matplotlib.axis.XTick at 0x2232212adc0>,
#   <matplotlib.axis.XTick at 0x2232212e310>,
#   <matplotlib.axis.XTick at 0x2232212e820>,
#   <matplotlib.axis.XTick at 0x2232212ed30>,
#   <matplotlib.axis.XTick at 0x22322134280>,
#   <matplotlib.axis.XTick at 0x2232212e460>,
#   <matplotlib.axis.XTick at 0x2232212a4f0>,
#   <matplotlib.axis.XTick at 0x2232211e520>,
#   <matplotlib.axis.XTick at 0x22322134790>,
#   <matplotlib.axis.XTick at 0x22322134ca0>,
#   <matplotlib.axis.XTick at 0x2232213c1f0>,
#   <matplotlib.axis.XTick at 0x2232213c700>,
#   <matplotlib.axis.XTick at 0x2232213cc10>,
#   <matplotlib.axis.XTick at 0x22322142160>,
#   <matplotlib.axis.XTick at 0x22322142670>,
#   <matplotlib.axis.XTick at 0x2232213c370>,
#   <matplotlib.axis.XTick at 0x2232211e940>,
#   <matplotlib.axis.XTick at 0x22322142700>,
#   <matplotlib.axis.XTick at 0x22322142af0>,
#   <matplotlib.axis.XTick at 0x2232214b040>,
#   <matplotlib.axis.XTick at 0x2232214b550>,
#   <matplotlib.axis.XTick at 0x2232214ba60>,
#   <matplotlib.axis.XTick at 0x2232214bf70>,
#   <matplotlib.axis.XTick at 0x2232214f4c0>,
#   <matplotlib.axis.XTick at 0x2232214b760>,
#   <matplotlib.axis.XTick at 0x22322142280>,
#   <matplotlib.axis.XTick at 0x2232213cc70>,
#   <matplotlib.axis.XTick at 0x2232214fa60>,
#   <matplotlib.axis.XTick at 0x2232214ff70>,
#   <matplotlib.axis.XTick at 0x223221564c0>,
#   <matplotlib.axis.XTick at 0x223221569d0>,
#   <matplotlib.axis.XTick at 0x22322156ee0>,
#   <matplotlib.axis.XTick at 0x2232215d430>,
#   <matplotlib.axis.XTick at 0x2232215d940>,
#   <matplotlib.axis.XTick at 0x22322156730>,
#   <matplotlib.axis.XTick at 0x2232214f850>,
#   <matplotlib.axis.XTick at 0x2232215dc10>,
#   <matplotlib.axis.XTick at 0x2232215de50>,
#   <matplotlib.axis.XTick at 0x223221633a0>,
#   <matplotlib.axis.XTick at 0x223221638b0>,
#   <matplotlib.axis.XTick at 0x22322163dc0>,
#   <matplotlib.axis.XTick at 0x22322169310>,
#   <matplotlib.axis.XTick at 0x22322169820>,
#   <matplotlib.axis.XTick at 0x22322169d30>,
#   <matplotlib.axis.XTick at 0x223221635b0>,
#   <matplotlib.axis.XTick at 0x223221421f0>,
#   <matplotlib.axis.XTick at 0x22322169910>,
#   <matplotlib.axis.XTick at 0x22322171280>,
#   <matplotlib.axis.XTick at 0x22322171790>,
#   <matplotlib.axis.XTick at 0x22322171ca0>,
#   <matplotlib.axis.XTick at 0x223221751f0>,
#   <matplotlib.axis.XTick at 0x22322175700>,
#   <matplotlib.axis.XTick at 0x22322175c10>,
#   <matplotlib.axis.XTick at 0x2232217b160>,
#   <matplotlib.axis.XTick at 0x22322175370>,
#   <matplotlib.axis.XTick at 0x22322171400>,
#   <matplotlib.axis.XTick at 0x223221630a0>,
#   <matplotlib.axis.XTick at 0x2232217b5e0>,
#   <matplotlib.axis.XTick at 0x2232217baf0>,
#   <matplotlib.axis.XTick at 0x22322182040>,
#   <matplotlib.axis.XTick at 0x22322182550>,
#   <matplotlib.axis.XTick at 0x22322182a60>,
#   <matplotlib.axis.XTick at 0x22322182f70>,
#   <matplotlib.axis.XTick at 0x223221827c0>,
#   <matplotlib.axis.XTick at 0x22322171df0>,
#   <matplotlib.axis.XTick at 0x2232217b700>,
#   <matplotlib.axis.XTick at 0x2232215db20>,
#   <matplotlib.axis.XTick at 0x22322125970>,
#   <matplotlib.axis.XTick at 0x22322188700>,
#   <matplotlib.axis.XTick at 0x22322188c10>,
#   <matplotlib.axis.XTick at 0x22322190160>,
#   <matplotlib.axis.XTick at 0x22322190670>,
#   <matplotlib.axis.XTick at 0x22322190b80>,
#   <matplotlib.axis.XTick at 0x22322188970>,
#   <matplotlib.axis.XTick at 0x22322169460>,
#   <matplotlib.axis.XTick at 0x22322190f10>,
#   <matplotlib.axis.XTick at 0x223221970d0>,
#   <matplotlib.axis.XTick at 0x223221975e0>,
#   <matplotlib.axis.XTick at 0x22322197af0>,
#   <matplotlib.axis.XTick at 0x2232219e040>,
#   <matplotlib.axis.XTick at 0x2232219e550>,
#   <matplotlib.axis.XTick at 0x2232219ea60>,
#   <matplotlib.axis.XTick at 0x2232219ef70>,
#   <matplotlib.axis.XTick at 0x2232219e730>,
#   <matplotlib.axis.XTick at 0x223221977c0>,
#   <matplotlib.axis.XTick at 0x2232217b2e0>,
#   <matplotlib.axis.XTick at 0x223221a24c0>,
#   <matplotlib.axis.XTick at 0x223221a29d0>,
#   <matplotlib.axis.XTick at 0x223221a2ee0>,
#   <matplotlib.axis.XTick at 0x223221aa430>,
#   <matplotlib.axis.XTick at 0x223221aa940>,
#   <matplotlib.axis.XTick at 0x223221aae50>,
#   <matplotlib.axis.XTick at 0x223221b03a0>,
#   <matplotlib.axis.XTick at 0x223221aa5b0>,
#   <matplotlib.axis.XTick at 0x223221a2640>,
#   <matplotlib.axis.XTick at 0x2232219e1c0>,
#   <matplotlib.axis.XTick at 0x223221b08b0>,
#   <matplotlib.axis.XTick at 0x223221b0dc0>,
#   <matplotlib.axis.XTick at 0x223221b7310>,
#   <matplotlib.axis.XTick at 0x223221b7820>,
#   <matplotlib.axis.XTick at 0x223221b7d30>,
#   <matplotlib.axis.XTick at 0x223221bd280>,
#   <matplotlib.axis.XTick at 0x223221bd790>,
#   <matplotlib.axis.XTick at 0x223221b7490>,
#   <matplotlib.axis.XTick at 0x223221b0610>,
#   <matplotlib.axis.XTick at 0x223221bd820>,
#   <matplotlib.axis.XTick at 0x223221bdc10>,
#   <matplotlib.axis.XTick at 0x223221c3160>,
#   <matplotlib.axis.XTick at 0x223221c3670>,
#   <matplotlib.axis.XTick at 0x223221c3b80>,
#   <matplotlib.axis.XTick at 0x223221c90d0>,
#   <matplotlib.axis.XTick at 0x223221c95e0>,
#   <matplotlib.axis.XTick at 0x223221c38e0>,
#   <matplotlib.axis.XTick at 0x223221bd970>,
#   <matplotlib.axis.XTick at 0x223221b7e50>,
#   <matplotlib.axis.XTick at 0x223221c9b80>,
#   <matplotlib.axis.XTick at 0x223221d00d0>,
#   <matplotlib.axis.XTick at 0x223221d05e0>,
#   <matplotlib.axis.XTick at 0x223221d0af0>,
#   <matplotlib.axis.XTick at 0x223221d5040>,
#   <matplotlib.axis.XTick at 0x223221d5550>,
#   <matplotlib.axis.XTick at 0x223221d5a60>,
#   <matplotlib.axis.XTick at 0x223221d07c0>,
#   <matplotlib.axis.XTick at 0x223221c98b0>,
#   <matplotlib.axis.XTick at 0x223221d5dc0>,
#   <matplotlib.axis.XTick at 0x223221d5f70>,
#   <matplotlib.axis.XTick at 0x223221dd4c0>,
#   <matplotlib.axis.XTick at 0x223221dd9d0>,
#   <matplotlib.axis.XTick at 0x223221ddee0>,
#   <matplotlib.axis.XTick at 0x223221e3430>,
#   <matplotlib.axis.XTick at 0x223221e3940>,
#   <matplotlib.axis.XTick at 0x223221e3e50>,
#   <matplotlib.axis.XTick at 0x223221e3520>,
#   <matplotlib.axis.XTick at 0x223221dd5b0>,
#   <matplotlib.axis.XTick at 0x22322188310>,
#   <matplotlib.axis.XTick at 0x223221e73a0>,
#   <matplotlib.axis.XTick at 0x223221e78b0>,
#   <matplotlib.axis.XTick at 0x223221e7dc0>,
#   <matplotlib.axis.XTick at 0x223221ef310>,
#   <matplotlib.axis.XTick at 0x223221ef820>,
#   <matplotlib.axis.XTick at 0x223221efd30>,
#   <matplotlib.axis.XTick at 0x223221f5280>,
#   <matplotlib.axis.XTick at 0x223221ef490>,
#   <matplotlib.axis.XTick at 0x223221e7520>,
#   <matplotlib.axis.XTick at 0x223221ddfd0>,
#   <matplotlib.axis.XTick at 0x223221f5700>,
#   <matplotlib.axis.XTick at 0x223221f5c10>,
#   <matplotlib.axis.XTick at 0x223221fc160>,
#   <matplotlib.axis.XTick at 0x223221fc670>,
#   <matplotlib.axis.XTick at 0x223221fcb80>,
#   <matplotlib.axis.XTick at 0x223222030d0>,
#   <matplotlib.axis.XTick at 0x223221fc8e0>,
#   <matplotlib.axis.XTick at 0x223221f5970>,
#   <matplotlib.axis.XTick at 0x223221e7ee0>,
#   <matplotlib.axis.XTick at 0x22322203670>,
#   <matplotlib.axis.XTick at 0x22322203b80>,
#   <matplotlib.axis.XTick at 0x223222090d0>,
#   <matplotlib.axis.XTick at 0x223222095e0>,
#   <matplotlib.axis.XTick at 0x22322209af0>,
#   <matplotlib.axis.XTick at 0x2232220e040>,
#   <matplotlib.axis.XTick at 0x2232220e550>,
#   <matplotlib.axis.XTick at 0x223222097c0>,
#   <matplotlib.axis.XTick at 0x22322203850>,
#   <matplotlib.axis.XTick at 0x223221fc1f0>,
#   <matplotlib.axis.XTick at 0x2232220ea60>,
#   <matplotlib.axis.XTick at 0x2232220ef70>,
#   <matplotlib.axis.XTick at 0x223222164c0>,
#   <matplotlib.axis.XTick at 0x223222169d0>,
#   <matplotlib.axis.XTick at 0x22322216ee0>,
#   <matplotlib.axis.XTick at 0x2232221b430>,
#   <matplotlib.axis.XTick at 0x2232221b940>,
#   <matplotlib.axis.XTick at 0x22322216520>,
#   <matplotlib.axis.XTick at 0x2232220e190>,
#   <matplotlib.axis.XTick at 0x2232221b4c0>,
#   <matplotlib.axis.XTick at 0x2232221be50>,
#   <matplotlib.axis.XTick at 0x223222233a0>,
#   <matplotlib.axis.XTick at 0x223222238b0>,
#   <matplotlib.axis.XTick at 0x22322223dc0>,
#   <matplotlib.axis.XTick at 0x22322229310>,
#   <matplotlib.axis.XTick at 0x22322229820>,
#   <matplotlib.axis.XTick at 0x22322229d30>,
#   <matplotlib.axis.XTick at 0x22322223580>,
#   <matplotlib.axis.XTick at 0x2232221bee0>,
#   <matplotlib.axis.XTick at 0x2232220e5b0>,
#   <matplotlib.axis.XTick at 0x223221d5c40>,
#   <matplotlib.axis.XTick at 0x223221a2130>,
#   <matplotlib.axis.XTick at 0x22322229580>,
#   <matplotlib.axis.XTick at 0x22322231280>,
#   <matplotlib.axis.XTick at 0x22322231790>,
#   <matplotlib.axis.XTick at 0x22322231ca0>,
#   <matplotlib.axis.XTick at 0x223222371f0>,
#   <matplotlib.axis.XTick at 0x223222313d0>,
#   <matplotlib.axis.XTick at 0x223221d5b50>,
#   <matplotlib.axis.XTick at 0x223221ef400>,
#   <matplotlib.axis.XTick at 0x223222375e0>,
#   <matplotlib.axis.XTick at 0x22322237af0>,
#   <matplotlib.axis.XTick at 0x2232223e040>,
#   <matplotlib.axis.XTick at 0x2232223e550>,
#   <matplotlib.axis.XTick at 0x2232223ea60>,
#   <matplotlib.axis.XTick at 0x2232223ef70>,
#   <matplotlib.axis.XTick at 0x223222434c0>,
#   <matplotlib.axis.XTick at 0x2232223e0d0>,
#   <matplotlib.axis.XTick at 0x22322223fa0>,
#   <matplotlib.axis.XTick at 0x22322243580>,
#   <matplotlib.axis.XTick at 0x22322243940>,
#   <matplotlib.axis.XTick at 0x22322243e50>,
#   <matplotlib.axis.XTick at 0x2232224b3a0>,
#   <matplotlib.axis.XTick at 0x2232224b8b0>,
#   <matplotlib.axis.XTick at 0x2232224bdc0>,
#   <matplotlib.axis.XTick at 0x22322251310>,
#   <matplotlib.axis.XTick at 0x2232224b940>,
#   <matplotlib.axis.XTick at 0x223222439d0>,
#   <matplotlib.axis.XTick at 0x22322237d60>,
#   <matplotlib.axis.XTick at 0x223222518b0>,
#   <matplotlib.axis.XTick at 0x22322251dc0>,
#   <matplotlib.axis.XTick at 0x22322258310>,
#   <matplotlib.axis.XTick at 0x22322258820>,
#   <matplotlib.axis.XTick at 0x22322258d30>,
#   <matplotlib.axis.XTick at 0x2232225e280>,
#   <matplotlib.axis.XTick at 0x2232225e790>,
#   <matplotlib.axis.XTick at 0x22322258a00>,
#   <matplotlib.axis.XTick at 0x22322251a90>,
#   <matplotlib.axis.XTick at 0x2232224b520>,
#   <matplotlib.axis.XTick at 0x2232225eca0>,
#   <matplotlib.axis.XTick at 0x223222651f0>,
#   <matplotlib.axis.XTick at 0x22322265700>,
#   <matplotlib.axis.XTick at 0x22322265c10>,
#   <matplotlib.axis.XTick at 0x2232226a160>,
#   <matplotlib.axis.XTick at 0x2232226a670>,
#   <matplotlib.axis.XTick at 0x2232226ab80>,
#   <matplotlib.axis.XTick at 0x22322265340>,
#   <matplotlib.axis.XTick at 0x223222519d0>,
#   <matplotlib.axis.XTick at 0x2232226a6d0>,
#   <matplotlib.axis.XTick at 0x223222710d0>,
#   <matplotlib.axis.XTick at 0x223222715e0>,
#   <matplotlib.axis.XTick at 0x22322271af0>],
#  [Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Ramicane'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Capomulin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Zoniferol'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Ketapril'),
#   Text(0, 0, 'Placebo'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Ceftamin'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Stelasyn'),
#   Text(0, 0, 'Propriva'),
#   Text(0, 0, 'Infubinol'),
#   Text(0, 0, 'Naftisol'),
#   Text(0, 0, 'Naftisol')])

# %%
####### Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(Mouse_and_Regimen)+10)
# Out:
# (0.0, 11.0)

# %%
###### Set a Title and labels
plt.title("Mouse Per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("mouse ID")
# Out:
# Text(243.40277777777777, 0.5, 'mouse ID')

# %%
###### show the grap
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
##### Split up our data into groups based upon 'mouse id' and 'gender'
Mouse_groups = new_df.groupby(['Sex','Mouse ID'])

# Create a new variable that holds the sum of our groups
sum_it_up = Mouse_groups.sum()
sum_it_up.head(40)
# Out:
#                  Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# Sex    Mouse ID
# Female a203              20          23         45           67.973419
#        a251              21          25         45           65.525743
#        a262              17          29         45           70.717621
#        a275              20          28         45           62.999356
#        a366              16          29         30           63.440686
#        a401               8          25         45           66.794156
#        a444              10          25         45           43.047543
#        a457              11          30         10           49.783419
#        a577               6          25         30           57.031862
#        a644               7          17         45           32.978522
#        a699               5          28         45           62.191414
#        a818              12          28         45           74.997764
#        a963              23          27         45           62.765093
#        b128               9          22         45           38.982878
#        b487               6          28         25           56.057749
#        b759              12          25         30           55.742829
#        b879               4          26         45           72.555239
#        c264              11          27         45           67.942121
#        c302              10          29         45           64.575222
#        c326              18          25          5           36.321346
#        c402               1          27         45           74.040390
#        c458              23          20         30           38.342008
#        c559              19          28         45           61.840058
#        c766              13          26         45           69.823146
#        c895               7          29         30           60.969711
#        c927               4          26         40           64.183229
#        d251               8          19         45           37.311236
#        e291              14          29         25           55.138953
#        f129              11          29         15           49.988302
#        f436               3          25         15           48.722078
#        f545              20          26         45           73.324432
#        g107               2          29         35           71.905117
#        g296              14          29         45           68.163195
#        g316              22          22         45           40.159220
#        g867               9          25         15           51.060419
#        g989              21          26         35           62.570880
#        h428               1          27          0           45.000000
#        i334               8          20         45           36.374510
#        i386              23          29         40           67.289621
#        i477               3          30         10           47.520632
#
#                  Metastatic Sites
# Sex    Mouse ID
# Female a203                     2
#        a251                     1
#        a262                     4
#        a275                     3
#        a366                     1
#        a401                     4
#        a444                     0
#        a457                     0
#        a577                     2
#        a644                     1
#        a699                     1
#        a818                     2
#        a963                     1
#        b128                     2
#        b487                     1
#        b759                     1
#        b879                     2
#        c264                     2
#        c302                     4
#        c326                     0
#        c402                     3
#        c458                     2
#        c559                     4
#        c766                     4
#        c895                     2
#        c927                     4
#        d251                     2
#        e291                     2
#        f129                     1
#        f436                     2
#        f545                     1
#        g107                     0
#        g296                     4
#        g316                     2
#        g867                     1
#        g989                     2
#        h428                     0
#        i334                     2
#        i386                     4
#        i477                     0

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
